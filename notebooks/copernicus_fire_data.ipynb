# %% [markdown]
# ## Fires in LA January 2025
# - https://edition.cnn.com/2025/01/08/us/maps-visuals-los-angeles-wildfires-dg/index.html

# %% [markdown]
# ## Fire Data
# - Using "Fire radiative power and active fire pixels" dataset: https://cds.climate.copernicus.eu/datasets/satellite-fire-radiative-power?tab=overview
#     - Resolution
#         - Space: 0.1x0.1 deg lat/lon
#         - Time: Daily (contrast with our hourly environmental data, what should we do here? prob find other data)
#     - Extent:
#         - Space: Entire world
#         - Time:

# %%
# API request for the data
import cdsapi

dataset = "satellite-fire-radiative-power"
request = {
    "variable": "all",
    "product_type": "gridded",
    "time_aggregation": "day",
    "horizontal_aggregation": "0_1_degree_x_0_1_degree",
    "satellite": ["sentinel_3a"],
    "observation_time": [
        "night",
        "day",
        "gasflares"
    ],
    "year": "2024",
    "month": ["01"],
    "day": ["01"],
    "version": ["1_2"]
}

# Comment these lines after you get the data (don't uncomment if data already there)

# client = cdsapi.Client()
# client.retrieve(dataset, request).download()

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
data = xr.open_dataset("../fire_data/copernicus/20240101-C3S-L3-FRP-SLSTR-P1D-0.1deg-S3A-daytime-fv1.2.nc")
data
# Out:
# <xarray.Dataset> Size: 311MB
# Dimensions:                            (lon: 3600, lat: 1800, time: 1, bounds: 2)
# Coordinates:
#   * lon                                (lon) float32 14kB -179.9 ... 179.9
#   * lat                                (lat) float32 7kB 89.95 89.85 ... -89.95
#   * time                               (time) datetime64[ns] 8B 2024-01-01
# Dimensions without coordinates: bounds
# Data variables:
#     lon_bounds                         (lon, bounds) float32 29kB ...
#     lat_bounds                         (lat, bounds) float32 14kB ...
#     time_bounds                        (time, bounds) datetime64[ns] 16B ...
#     fire_pixels                        (time, lat, lon) float64 52MB ...
#     frp                                (time, lat, lon) float32 26MB ...
#     frp_unc                            (time, lat, lon) float32 26MB ...
#     total_pixels                       (time, lat, lon) float64 52MB ...
#     surface_conditions_flag_pixels     (time, lat, lon) float64 52MB ...
#     atmospheric_condition_flag_pixels  (time, lat, lon) float64 52MB ...
#     atmospheric_condition_fraction     (time, lat, lon) float32 26MB ...
#     fire_weighted_pixels               (time, lat, lon) float32 26MB ...
# Attributes: (12/40)
#     title:                      ECMWF C3S Gridded OLCI Fire Radiative Power p...
#     institution:                King's College London, Brockmann Consult GmbH
#     source:                     ESA Sentinel-3 A+B SLSTR FRP
#     history:                    Created on 20241019T030641Z
#     references:                 See https://climate.copernicus.eu/
#     tracking_id:                badf07ee-75f1-4d9b-9b24-180320fe44cb
#     ...                         ...
#     spatial_resolution:         0.1 degrees
#     geospatial_lon_units:       degrees_east
#     geospatial_lat_units:       degrees_north
#     geospatial_lon_resolution:  0.1
#     geospatial_lat_resolution:  0.1
#     id:                         20240101-C3S-L3-FRP-SLSTR-P1D-0.1deg-S3A-dayt...

# %%
subset = data.sel(lon=slice(-118.952181, -117.444077), lat=slice(34.823302, 34.053039))
subset
# Out:
# <xarray.Dataset> Size: 6kB
# Dimensions:                            (lon: 16, lat: 7, time: 1, bounds: 2)
# Coordinates:
#   * lon                                (lon) float32 64B -118.9 ... -117.4
#   * lat                                (lat) float32 28B 34.75 34.65 ... 34.15
#   * time                               (time) datetime64[ns] 8B 2024-01-01
# Dimensions without coordinates: bounds
# Data variables:
#     lon_bounds                         (lon, bounds) float32 128B ...
#     lat_bounds                         (lat, bounds) float32 56B ...
#     time_bounds                        (time, bounds) datetime64[ns] 16B ...
#     fire_pixels                        (time, lat, lon) float64 896B ...
#     frp                                (time, lat, lon) float32 448B ...
#     frp_unc                            (time, lat, lon) float32 448B ...
#     total_pixels                       (time, lat, lon) float64 896B ...
#     surface_conditions_flag_pixels     (time, lat, lon) float64 896B ...
#     atmospheric_condition_flag_pixels  (time, lat, lon) float64 896B ...
#     atmospheric_condition_fraction     (time, lat, lon) float32 448B ...
#     fire_weighted_pixels               (time, lat, lon) float32 448B ...
# Attributes: (12/40)
#     title:                      ECMWF C3S Gridded OLCI Fire Radiative Power p...
#     institution:                King's College London, Brockmann Consult GmbH
#     source:                     ESA Sentinel-3 A+B SLSTR FRP
#     history:                    Created on 20241019T030641Z
#     references:                 See https://climate.copernicus.eu/
#     tracking_id:                badf07ee-75f1-4d9b-9b24-180320fe44cb
#     ...                         ...
#     spatial_resolution:         0.1 degrees
#     geospatial_lon_units:       degrees_east
#     geospatial_lat_units:       degrees_north
#     geospatial_lon_resolution:  0.1
#     geospatial_lat_resolution:  0.1
#     id:                         20240101-C3S-L3-FRP-SLSTR-P1D-0.1deg-S3A-dayt...

# %%
subset.lat.values, subset.lon.values
# Out:
# (array([34.75, 34.65, 34.55, 34.45, 34.35, 34.25, 34.15], dtype=float32),
#  array([-118.95, -118.85, -118.75, -118.65, -118.55, -118.45, -118.35,
#         -118.25, -118.15, -118.05, -117.95, -117.85, -117.75, -117.65,
#         -117.55, -117.45], dtype=float32))

# %%
subset.fire_weighted_pixels
# Out:
# <xarray.DataArray 'fire_weighted_pixels' (time: 1, lat: 7, lon: 16)> Size: 448B
# [112 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float32 64B -118.9 -118.8 -118.8 ... -117.7 -117.6 -117.4
#   * lat      (lat) float32 28B 34.75 34.65 34.55 34.45 34.35 34.25 34.15
#   * time     (time) datetime64[ns] 8B 2024-01-01
# Attributes:
#     units:      1
#     long_name:  Number of S3A daytime active fire pixels weighted by atmosphe...
